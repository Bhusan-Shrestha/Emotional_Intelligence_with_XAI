# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import joblib
import seaborn as sns
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

print("TensorFlow version:",tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %%
# Define paths
train_path = r'D:\ML_Project\Emotional_Intelligence_with_XAI\Data_Sets\train'
test_path = r'D:\ML_Project\Emotional_Intelligence_with_XAI\Data_Sets\test'

# Emotion labels
emotion_labels = {
    0: 'angry',
    1: 'disgusted',
    2: 'fearful',
    3: 'happy',
    4: 'sad',
    5: 'surprised',
    6: 'neutral'
}

def load_dataset(dataset_path):
    images = []
    labels = []
    
    for emotion_num, emotion_name in emotion_labels.items():
        emotion_path = os.path.join(dataset_path, emotion_name)
        
        # Check if directory exists
        if not os.path.isdir(emotion_path):
            print(f"Warning: Directory {emotion_path} not found. Skipping...")
            continue
            
        for img_file in os.listdir(emotion_path):
            if img_file.endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(emotion_path, img_file)
                
                try:
                    # Read and preprocess image
                    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                    img = cv2.resize(img, (48, 48))
                    
                    # Normalize pixel values
                    img = img / 255.0
                    
                    images.append(img)
                    labels.append(emotion_num)
                except Exception as e:
                    print(f"Error loading image {img_path}: {e}")
    
    # Convert to numpy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels

# Load training and test data
print("Loading training data...")
train_images, train_labels = load_dataset(train_path)
print("Loading test data...")
test_images, test_labels = load_dataset(test_path)

# Reshape images for CNN input
train_images = train_images.reshape(-1, 48, 48, 1)
test_images = test_images.reshape(-1, 48, 48, 1)

# One-hot encode labels
train_labels = to_categorical(train_labels, num_classes=7)
test_labels = to_categorical(test_labels, num_classes=7)

# Split into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    train_images, 
    train_labels, 
    test_size=0.2, 
    random_state=42,
    stratify=train_labels  # Maintain class distribution
)

print("\nDataset Statistics:")
print(f"Training set shape: {X_train.shape} ({(X_train.shape[0]/len(train_images)*100):.1f}% of total)")
print(f"Validation set shape: {X_val.shape} ({(X_val.shape[0]/len(train_images)*100):.1f}% of total)")
print(f"Test set shape: {test_images.shape}")

# Visualize class distribution
def plot_class_distribution(labels, title):
    class_counts = np.sum(labels, axis=0)
    plt.figure(figsize=(10, 5))
    plt.bar(emotion_labels.values(), class_counts)
    plt.title(title)
    plt.xlabel('Emotion Class')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45)
    plt.show()

plot_class_distribution(train_labels, 'Training Set Class Distribution')
plot_class_distribution(test_labels, 'Test Set Class Distribution')
# Out:
# Loading training data...
# Loading test data...
#
# Dataset Statistics:
# Training set shape: (22967, 48, 48, 1) (80.0% of total)
# Validation set shape: (5742, 48, 48, 1) (20.0% of total)
# Test set shape: (7178, 48, 48, 1)

# %% [markdown]
# # Create data generator for augmentation

# %%
# Create data generation for augentation
train_datagen = ImageDataGenerator(
    rotation_range = 15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_datagen.fit(X_train)

# %%
def create_model():
    model = Sequential()
    
    # First Conv Block
    model.add(Conv2D(64, (3,3), padding='same', activation='relu', input_shape=(48, 48, 1)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    # Second Conv Block
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    # Third Conv Block
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    # Fully Connected Layers
    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(7, activation='softmax'))
    
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batch_normalization_4 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batch_normalization_5 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  batch_normalization_6 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 11,120,583
# Trainable params: 11,115,719
# Non-trainable params: 4,864
# _________________________________________________________________

# %%
# Define Optimize
optimize = Adam(learning_rate=0.0001)

# Compile the model
model.compile(optimizer=optimize, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Callbacks
checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=0.00001,
    verbose=1
)

# %%
# Training parameters
batch_size=64
epochs=100

# Train the model
history = model.fit(
    train_datagen.flow(X_train,y_train,batch_size=batch_size),
    steps_per_epoch=len(X_train) // batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint,early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 358/358 [==============================] - ETA: 0s - loss: 2.8279 - accuracy: 0.1909
# Epoch 1: val_accuracy improved from -inf to 0.19453, saving model to best_model.h5
# 358/358 [==============================] - 500s 1s/step - loss: 2.8279 - accuracy: 0.1909 - val_loss: 2.3611 - val_accuracy: 0.1945 - lr: 1.0000e-04
# Epoch 2/100
# 358/358 [==============================] - ETA: 0s - loss: 2.4662 - accuracy: 0.2269
# Epoch 2: val_accuracy improved from 0.19453 to 0.34343, saving model to best_model.h5
# 358/358 [==============================] - 505s 1s/step - loss: 2.4662 - accuracy: 0.2269 - val_loss: 1.7722 - val_accuracy: 0.3434 - lr: 1.0000e-04
# Epoch 3/100
# 358/358 [==============================] - ETA: 0s - loss: 2.3001 - accuracy: 0.2466
# Epoch 3: val_accuracy improved from 0.34343 to 0.36886, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 2.3001 - accuracy: 0.2466 - val_loss: 1.6846 - val_accuracy: 0.3689 - lr: 1.0000e-04
# Epoch 4/100
# 358/358 [==============================] - ETA: 0s - loss: 2.1379 - accuracy: 0.2764
# Epoch 4: val_accuracy improved from 0.36886 to 0.39115, saving model to best_model.h5
# 358/358 [==============================] - 486s 1s/step - loss: 2.1379 - accuracy: 0.2764 - val_loss: 1.6091 - val_accuracy: 0.3912 - lr: 1.0000e-04
# Epoch 5/100
# 358/358 [==============================] - ETA: 0s - loss: 2.0205 - accuracy: 0.3001
# Epoch 5: val_accuracy improved from 0.39115 to 0.41397, saving model to best_model.h5
# 358/358 [==============================] - 484s 1s/step - loss: 2.0205 - accuracy: 0.3001 - val_loss: 1.5833 - val_accuracy: 0.4140 - lr: 1.0000e-04
# Epoch 6/100
# 358/358 [==============================] - ETA: 0s - loss: 1.9274 - accuracy: 0.3191
# Epoch 6: val_accuracy improved from 0.41397 to 0.42825, saving model to best_model.h5
# 358/358 [==============================] - 485s 1s/step - loss: 1.9274 - accuracy: 0.3191 - val_loss: 1.5220 - val_accuracy: 0.4282 - lr: 1.0000e-04
# Epoch 7/100
# 358/358 [==============================] - ETA: 0s - loss: 1.8430 - accuracy: 0.3403
# Epoch 7: val_accuracy improved from 0.42825 to 0.44497, saving model to best_model.h5
# 358/358 [==============================] - 485s 1s/step - loss: 1.8430 - accuracy: 0.3403 - val_loss: 1.4527 - val_accuracy: 0.4450 - lr: 1.0000e-04
# Epoch 8/100
# 358/358 [==============================] - ETA: 0s - loss: 1.7608 - accuracy: 0.3636
# Epoch 8: val_accuracy improved from 0.44497 to 0.45594, saving model to best_model.h5
# 358/358 [==============================] - 486s 1s/step - loss: 1.7608 - accuracy: 0.3636 - val_loss: 1.4206 - val_accuracy: 0.4559 - lr: 1.0000e-04
# Epoch 9/100
# 358/358 [==============================] - ETA: 0s - loss: 1.6916 - accuracy: 0.3779
# Epoch 9: val_accuracy improved from 0.45594 to 0.48241, saving model to best_model.h5
# 358/358 [==============================] - 488s 1s/step - loss: 1.6916 - accuracy: 0.3779 - val_loss: 1.3682 - val_accuracy: 0.4824 - lr: 1.0000e-04
# Epoch 10/100
# 358/358 [==============================] - ETA: 0s - loss: 1.6299 - accuracy: 0.3979
# Epoch 10: val_accuracy improved from 0.48241 to 0.49234, saving model to best_model.h5
# 358/358 [==============================] - 487s 1s/step - loss: 1.6299 - accuracy: 0.3979 - val_loss: 1.3278 - val_accuracy: 0.4923 - lr: 1.0000e-04
# Epoch 11/100
# 358/358 [==============================] - ETA: 0s - loss: 1.5712 - accuracy: 0.4114
# Epoch 11: val_accuracy improved from 0.49234 to 0.51289, saving model to best_model.h5
# 358/358 [==============================] - 486s 1s/step - loss: 1.5712 - accuracy: 0.4114 - val_loss: 1.2812 - val_accuracy: 0.5129 - lr: 1.0000e-04
# Epoch 12/100
# 358/358 [==============================] - ETA: 0s - loss: 1.5061 - accuracy: 0.4299
# Epoch 12: val_accuracy did not improve from 0.51289
# 358/358 [==============================] - 486s 1s/step - loss: 1.5061 - accuracy: 0.4299 - val_loss: 1.3431 - val_accuracy: 0.5099 - lr: 1.0000e-04
# Epoch 13/100
# 358/358 [==============================] - ETA: 0s - loss: 1.4634 - accuracy: 0.4478
# Epoch 13: val_accuracy improved from 0.51289 to 0.52839, saving model to best_model.h5
# 358/358 [==============================] - 493s 1s/step - loss: 1.4634 - accuracy: 0.4478 - val_loss: 1.2436 - val_accuracy: 0.5284 - lr: 1.0000e-04
# Epoch 14/100
# 358/358 [==============================] - ETA: 0s - loss: 1.4268 - accuracy: 0.4608
# Epoch 14: val_accuracy improved from 0.52839 to 0.54110, saving model to best_model.h5
# 358/358 [==============================] - 495s 1s/step - loss: 1.4268 - accuracy: 0.4608 - val_loss: 1.2107 - val_accuracy: 0.5411 - lr: 1.0000e-04
# Epoch 15/100
# 358/358 [==============================] - ETA: 0s - loss: 1.3853 - accuracy: 0.4727
# Epoch 15: val_accuracy improved from 0.54110 to 0.55590, saving model to best_model.h5
# 358/358 [==============================] - 493s 1s/step - loss: 1.3853 - accuracy: 0.4727 - val_loss: 1.1688 - val_accuracy: 0.5559 - lr: 1.0000e-04
# Epoch 16/100
# 358/358 [==============================] - ETA: 0s - loss: 1.3473 - accuracy: 0.4870
# Epoch 16: val_accuracy did not improve from 0.55590
# 358/358 [==============================] - 491s 1s/step - loss: 1.3473 - accuracy: 0.4870 - val_loss: 1.2532 - val_accuracy: 0.5181 - lr: 1.0000e-04
# Epoch 17/100
# 358/358 [==============================] - ETA: 0s - loss: 1.3177 - accuracy: 0.4987
# Epoch 17: val_accuracy improved from 0.55590 to 0.55712, saving model to best_model.h5
# 358/358 [==============================] - 490s 1s/step - loss: 1.3177 - accuracy: 0.4987 - val_loss: 1.1655 - val_accuracy: 0.5571 - lr: 1.0000e-04
# Epoch 18/100
# 358/358 [==============================] - ETA: 0s - loss: 1.2885 - accuracy: 0.5085
# Epoch 18: val_accuracy did not improve from 0.55712
# 358/358 [==============================] - 493s 1s/step - loss: 1.2885 - accuracy: 0.5085 - val_loss: 1.1679 - val_accuracy: 0.5571 - lr: 1.0000e-04
# Epoch 19/100
# 358/358 [==============================] - ETA: 0s - loss: 1.2738 - accuracy: 0.5138
# Epoch 19: val_accuracy improved from 0.55712 to 0.58377, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.2738 - accuracy: 0.5138 - val_loss: 1.0975 - val_accuracy: 0.5838 - lr: 1.0000e-04
# Epoch 20/100
# 358/358 [==============================] - ETA: 0s - loss: 1.2533 - accuracy: 0.5242
# Epoch 20: val_accuracy improved from 0.58377 to 0.58777, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.2533 - accuracy: 0.5242 - val_loss: 1.1046 - val_accuracy: 0.5878 - lr: 1.0000e-04
# Epoch 21/100
# 358/358 [==============================] - ETA: 0s - loss: 1.2289 - accuracy: 0.5325
# Epoch 21: val_accuracy improved from 0.58777 to 0.58882, saving model to best_model.h5
# 358/358 [==============================] - 500s 1s/step - loss: 1.2289 - accuracy: 0.5325 - val_loss: 1.0747 - val_accuracy: 0.5888 - lr: 1.0000e-04
# Epoch 22/100
# 358/358 [==============================] - ETA: 0s - loss: 1.2062 - accuracy: 0.5446
# Epoch 22: val_accuracy did not improve from 0.58882
# 358/358 [==============================] - 492s 1s/step - loss: 1.2062 - accuracy: 0.5446 - val_loss: 1.1026 - val_accuracy: 0.5834 - lr: 1.0000e-04
# Epoch 23/100
# 358/358 [==============================] - ETA: 0s - loss: 1.1929 - accuracy: 0.5482
# Epoch 23: val_accuracy improved from 0.58882 to 0.59892, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.1929 - accuracy: 0.5482 - val_loss: 1.0497 - val_accuracy: 0.5989 - lr: 1.0000e-04
# Epoch 24/100
# 358/358 [==============================] - ETA: 0s - loss: 1.1795 - accuracy: 0.5529
# Epoch 24: val_accuracy improved from 0.59892 to 0.60310, saving model to best_model.h5
# 358/358 [==============================] - 493s 1s/step - loss: 1.1795 - accuracy: 0.5529 - val_loss: 1.0374 - val_accuracy: 0.6031 - lr: 1.0000e-04
# Epoch 25/100
# 358/358 [==============================] - ETA: 0s - loss: 1.1575 - accuracy: 0.5620
# Epoch 25: val_accuracy improved from 0.60310 to 0.60362, saving model to best_model.h5
# 358/358 [==============================] - 490s 1s/step - loss: 1.1575 - accuracy: 0.5620 - val_loss: 1.0339 - val_accuracy: 0.6036 - lr: 1.0000e-04
# Epoch 26/100
# 358/358 [==============================] - ETA: 0s - loss: 1.1429 - accuracy: 0.5635
# Epoch 26: val_accuracy did not improve from 0.60362
# 358/358 [==============================] - 490s 1s/step - loss: 1.1429 - accuracy: 0.5635 - val_loss: 1.0646 - val_accuracy: 0.5980 - lr: 1.0000e-04
# Epoch 27/100
# 358/358 [==============================] - ETA: 0s - loss: 1.1289 - accuracy: 0.5748
# Epoch 27: val_accuracy improved from 0.60362 to 0.60798, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.1289 - accuracy: 0.5748 - val_loss: 1.0284 - val_accuracy: 0.6080 - lr: 1.0000e-04
# Epoch 28/100
# 358/358 [==============================] - ETA: 0s - loss: 1.1185 - accuracy: 0.5793
# Epoch 28: val_accuracy improved from 0.60798 to 0.61808, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.1185 - accuracy: 0.5793 - val_loss: 1.0113 - val_accuracy: 0.6181 - lr: 1.0000e-04
# Epoch 29/100
# 358/358 [==============================] - ETA: 0s - loss: 1.1056 - accuracy: 0.5798
# Epoch 29: val_accuracy did not improve from 0.61808
# 358/358 [==============================] - 492s 1s/step - loss: 1.1056 - accuracy: 0.5798 - val_loss: 1.0122 - val_accuracy: 0.6118 - lr: 1.0000e-04
# Epoch 30/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0965 - accuracy: 0.5871
# Epoch 30: val_accuracy improved from 0.61808 to 0.62330, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.0965 - accuracy: 0.5871 - val_loss: 1.0001 - val_accuracy: 0.6233 - lr: 1.0000e-04
# Epoch 31/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0834 - accuracy: 0.5914
# Epoch 31: val_accuracy did not improve from 0.62330
# 358/358 [==============================] - 491s 1s/step - loss: 1.0834 - accuracy: 0.5914 - val_loss: 1.0058 - val_accuracy: 0.6198 - lr: 1.0000e-04
# Epoch 32/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0702 - accuracy: 0.5969
# Epoch 32: val_accuracy did not improve from 0.62330
# 358/358 [==============================] - 490s 1s/step - loss: 1.0702 - accuracy: 0.5969 - val_loss: 0.9988 - val_accuracy: 0.6224 - lr: 1.0000e-04
# Epoch 33/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0595 - accuracy: 0.6040
# Epoch 33: val_accuracy did not improve from 0.62330
# 358/358 [==============================] - 490s 1s/step - loss: 1.0595 - accuracy: 0.6040 - val_loss: 1.0320 - val_accuracy: 0.6130 - lr: 1.0000e-04
# Epoch 34/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0472 - accuracy: 0.6009
# Epoch 34: val_accuracy did not improve from 0.62330
# 358/358 [==============================] - 493s 1s/step - loss: 1.0472 - accuracy: 0.6009 - val_loss: 1.0043 - val_accuracy: 0.6223 - lr: 1.0000e-04
# Epoch 35/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0429 - accuracy: 0.6026
# Epoch 35: val_accuracy improved from 0.62330 to 0.63932, saving model to best_model.h5
# 358/358 [==============================] - 495s 1s/step - loss: 1.0429 - accuracy: 0.6026 - val_loss: 0.9764 - val_accuracy: 0.6393 - lr: 1.0000e-04
# Epoch 36/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0311 - accuracy: 0.6080
# Epoch 36: val_accuracy did not improve from 0.63932
# 358/358 [==============================] - 490s 1s/step - loss: 1.0311 - accuracy: 0.6080 - val_loss: 0.9763 - val_accuracy: 0.6351 - lr: 1.0000e-04
# Epoch 37/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0177 - accuracy: 0.6184
# Epoch 37: val_accuracy did not improve from 0.63932
# 358/358 [==============================] - 490s 1s/step - loss: 1.0177 - accuracy: 0.6184 - val_loss: 0.9925 - val_accuracy: 0.6231 - lr: 1.0000e-04
# Epoch 38/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0140 - accuracy: 0.6185
# Epoch 38: val_accuracy improved from 0.63932 to 0.64316, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.0140 - accuracy: 0.6185 - val_loss: 0.9506 - val_accuracy: 0.6432 - lr: 1.0000e-04
# Epoch 39/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0043 - accuracy: 0.6205
# Epoch 39: val_accuracy improved from 0.64316 to 0.64716, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 1.0043 - accuracy: 0.6205 - val_loss: 0.9443 - val_accuracy: 0.6472 - lr: 1.0000e-04
# Epoch 40/100
# 358/358 [==============================] - ETA: 0s - loss: 1.0023 - accuracy: 0.6221
# Epoch 40: val_accuracy did not improve from 0.64716
# 358/358 [==============================] - 491s 1s/step - loss: 1.0023 - accuracy: 0.6221 - val_loss: 0.9513 - val_accuracy: 0.6463 - lr: 1.0000e-04
# Epoch 41/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9887 - accuracy: 0.6259
# Epoch 41: val_accuracy did not improve from 0.64716
# 358/358 [==============================] - 491s 1s/step - loss: 0.9887 - accuracy: 0.6259 - val_loss: 0.9746 - val_accuracy: 0.6350 - lr: 1.0000e-04
# Epoch 42/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9868 - accuracy: 0.6258
# Epoch 42: val_accuracy did not improve from 0.64716
# 358/358 [==============================] - 491s 1s/step - loss: 0.9868 - accuracy: 0.6258 - val_loss: 0.9455 - val_accuracy: 0.6465 - lr: 1.0000e-04
# Epoch 43/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.6342
# Epoch 43: val_accuracy did not improve from 0.64716
# 358/358 [==============================] - 491s 1s/step - loss: 0.9740 - accuracy: 0.6342 - val_loss: 0.9538 - val_accuracy: 0.6426 - lr: 1.0000e-04
# Epoch 44/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9681 - accuracy: 0.6365
# Epoch 44: val_accuracy improved from 0.64716 to 0.65831, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 0.9681 - accuracy: 0.6365 - val_loss: 0.9201 - val_accuracy: 0.6583 - lr: 1.0000e-04
# Epoch 45/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9611 - accuracy: 0.6404
# Epoch 45: val_accuracy did not improve from 0.65831
# 358/358 [==============================] - 492s 1s/step - loss: 0.9611 - accuracy: 0.6404 - val_loss: 0.9529 - val_accuracy: 0.6452 - lr: 1.0000e-04
# Epoch 46/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9524 - accuracy: 0.6419
# Epoch 46: val_accuracy did not improve from 0.65831
# 358/358 [==============================] - 489s 1s/step - loss: 0.9524 - accuracy: 0.6419 - val_loss: 0.9337 - val_accuracy: 0.6491 - lr: 1.0000e-04
# Epoch 47/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9459 - accuracy: 0.6420
# Epoch 47: val_accuracy did not improve from 0.65831
# 358/358 [==============================] - 490s 1s/step - loss: 0.9459 - accuracy: 0.6420 - val_loss: 0.9260 - val_accuracy: 0.6534 - lr: 1.0000e-04
# Epoch 48/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9364 - accuracy: 0.6466
# Epoch 48: val_accuracy did not improve from 0.65831
# 358/358 [==============================] - 489s 1s/step - loss: 0.9364 - accuracy: 0.6466 - val_loss: 0.9270 - val_accuracy: 0.6541 - lr: 1.0000e-04
# Epoch 49/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9281 - accuracy: 0.6521
# Epoch 49: val_accuracy did not improve from 0.65831
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 358/358 [==============================] - 515s 1s/step - loss: 0.9281 - accuracy: 0.6521 - val_loss: 0.9237 - val_accuracy: 0.6550 - lr: 1.0000e-04
# Epoch 50/100
# 358/358 [==============================] - ETA: 0s - loss: 0.9107 - accuracy: 0.6577
# Epoch 50: val_accuracy improved from 0.65831 to 0.66649, saving model to best_model.h5
# 358/358 [==============================] - 492s 1s/step - loss: 0.9107 - accuracy: 0.6577 - val_loss: 0.8952 - val_accuracy: 0.6665 - lr: 2.0000e-05
# Epoch 51/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8975 - accuracy: 0.6637
# Epoch 51: val_accuracy did not improve from 0.66649
# 358/358 [==============================] - 493s 1s/step - loss: 0.8975 - accuracy: 0.6637 - val_loss: 0.8997 - val_accuracy: 0.6653 - lr: 2.0000e-05
# Epoch 52/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8949 - accuracy: 0.6647
# Epoch 52: val_accuracy improved from 0.66649 to 0.66823, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 0.8949 - accuracy: 0.6647 - val_loss: 0.8954 - val_accuracy: 0.6682 - lr: 2.0000e-05
# Epoch 53/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8870 - accuracy: 0.6689
# Epoch 53: val_accuracy did not improve from 0.66823
# 358/358 [==============================] - 494s 1s/step - loss: 0.8870 - accuracy: 0.6689 - val_loss: 0.9019 - val_accuracy: 0.6682 - lr: 2.0000e-05
# Epoch 54/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8764 - accuracy: 0.6727
# Epoch 54: val_accuracy improved from 0.66823 to 0.67154, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 0.8764 - accuracy: 0.6727 - val_loss: 0.8931 - val_accuracy: 0.6715 - lr: 2.0000e-05
# Epoch 55/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8706 - accuracy: 0.6721
# Epoch 55: val_accuracy did not improve from 0.67154
# 358/358 [==============================] - 491s 1s/step - loss: 0.8706 - accuracy: 0.6721 - val_loss: 0.8947 - val_accuracy: 0.6700 - lr: 2.0000e-05
# Epoch 56/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8719 - accuracy: 0.6739
# Epoch 56: val_accuracy did not improve from 0.67154
# 358/358 [==============================] - 492s 1s/step - loss: 0.8719 - accuracy: 0.6739 - val_loss: 0.8928 - val_accuracy: 0.6695 - lr: 2.0000e-05
# Epoch 57/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8708 - accuracy: 0.6733
# Epoch 57: val_accuracy did not improve from 0.67154
# 358/358 [==============================] - 492s 1s/step - loss: 0.8708 - accuracy: 0.6733 - val_loss: 0.8938 - val_accuracy: 0.6705 - lr: 2.0000e-05
# Epoch 58/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8723 - accuracy: 0.6748
# Epoch 58: val_accuracy improved from 0.67154 to 0.67294, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 0.8723 - accuracy: 0.6748 - val_loss: 0.8960 - val_accuracy: 0.6729 - lr: 2.0000e-05
# Epoch 59/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8665 - accuracy: 0.6739
# Epoch 59: val_accuracy did not improve from 0.67294
# 358/358 [==============================] - 491s 1s/step - loss: 0.8665 - accuracy: 0.6739 - val_loss: 0.8996 - val_accuracy: 0.6700 - lr: 2.0000e-05
# Epoch 60/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8671 - accuracy: 0.6761
# Epoch 60: val_accuracy did not improve from 0.67294
# 358/358 [==============================] - 492s 1s/step - loss: 0.8671 - accuracy: 0.6761 - val_loss: 0.8905 - val_accuracy: 0.6714 - lr: 2.0000e-05
# Epoch 61/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8589 - accuracy: 0.6792
# Epoch 61: val_accuracy improved from 0.67294 to 0.67659, saving model to best_model.h5
# 358/358 [==============================] - 491s 1s/step - loss: 0.8589 - accuracy: 0.6792 - val_loss: 0.8858 - val_accuracy: 0.6766 - lr: 2.0000e-05
# Epoch 62/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8571 - accuracy: 0.6786
# Epoch 62: val_accuracy did not improve from 0.67659
# 358/358 [==============================] - 492s 1s/step - loss: 0.8571 - accuracy: 0.6786 - val_loss: 0.8945 - val_accuracy: 0.6703 - lr: 2.0000e-05
# Epoch 63/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8547 - accuracy: 0.6817
# Epoch 63: val_accuracy did not improve from 0.67659
# 358/358 [==============================] - 491s 1s/step - loss: 0.8547 - accuracy: 0.6817 - val_loss: 0.8897 - val_accuracy: 0.6750 - lr: 2.0000e-05
# Epoch 64/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8584 - accuracy: 0.6781
# Epoch 64: val_accuracy did not improve from 0.67659
# 358/358 [==============================] - 490s 1s/step - loss: 0.8584 - accuracy: 0.6781 - val_loss: 0.8935 - val_accuracy: 0.6736 - lr: 2.0000e-05
# Epoch 65/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8465 - accuracy: 0.6863
# Epoch 65: val_accuracy did not improve from 0.67659
# 358/358 [==============================] - 491s 1s/step - loss: 0.8465 - accuracy: 0.6863 - val_loss: 0.8971 - val_accuracy: 0.6695 - lr: 2.0000e-05
# Epoch 66/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8443 - accuracy: 0.6851
# Epoch 66: val_accuracy did not improve from 0.67659
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1e-05.
# 358/358 [==============================] - 491s 1s/step - loss: 0.8443 - accuracy: 0.6851 - val_loss: 0.8926 - val_accuracy: 0.6708 - lr: 2.0000e-05
# Epoch 67/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8409 - accuracy: 0.6880
# Epoch 67: val_accuracy improved from 0.67659 to 0.67694, saving model to best_model.h5
# 358/358 [==============================] - 492s 1s/step - loss: 0.8409 - accuracy: 0.6880 - val_loss: 0.8844 - val_accuracy: 0.6769 - lr: 1.0000e-05
# Epoch 68/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8439 - accuracy: 0.6836
# Epoch 68: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8439 - accuracy: 0.6836 - val_loss: 0.8873 - val_accuracy: 0.6750 - lr: 1.0000e-05
# Epoch 69/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8379 - accuracy: 0.6862
# Epoch 69: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8379 - accuracy: 0.6862 - val_loss: 0.8870 - val_accuracy: 0.6743 - lr: 1.0000e-05
# Epoch 70/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8343 - accuracy: 0.6871
# Epoch 70: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8343 - accuracy: 0.6871 - val_loss: 0.8863 - val_accuracy: 0.6761 - lr: 1.0000e-05
# Epoch 71/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8374 - accuracy: 0.6839
# Epoch 71: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 492s 1s/step - loss: 0.8374 - accuracy: 0.6839 - val_loss: 0.8845 - val_accuracy: 0.6757 - lr: 1.0000e-05
# Epoch 72/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8389 - accuracy: 0.6863
# Epoch 72: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8389 - accuracy: 0.6863 - val_loss: 0.8869 - val_accuracy: 0.6752 - lr: 1.0000e-05
# Epoch 73/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8300 - accuracy: 0.6913
# Epoch 73: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8300 - accuracy: 0.6913 - val_loss: 0.8924 - val_accuracy: 0.6742 - lr: 1.0000e-05
# Epoch 74/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8340 - accuracy: 0.6904
# Epoch 74: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 492s 1s/step - loss: 0.8340 - accuracy: 0.6904 - val_loss: 0.8895 - val_accuracy: 0.6749 - lr: 1.0000e-05
# Epoch 75/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8283 - accuracy: 0.6887
# Epoch 75: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 492s 1s/step - loss: 0.8283 - accuracy: 0.6887 - val_loss: 0.8873 - val_accuracy: 0.6752 - lr: 1.0000e-05
# Epoch 76/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8303 - accuracy: 0.6915
# Epoch 76: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 490s 1s/step - loss: 0.8303 - accuracy: 0.6915 - val_loss: 0.8854 - val_accuracy: 0.6759 - lr: 1.0000e-05
# Epoch 77/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8265 - accuracy: 0.6899
# Epoch 77: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8265 - accuracy: 0.6899 - val_loss: 0.8887 - val_accuracy: 0.6712 - lr: 1.0000e-05
# Epoch 78/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8280 - accuracy: 0.6933
# Epoch 78: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8280 - accuracy: 0.6933 - val_loss: 0.8887 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 79/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8215 - accuracy: 0.6914
# Epoch 79: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 490s 1s/step - loss: 0.8215 - accuracy: 0.6914 - val_loss: 0.8882 - val_accuracy: 0.6743 - lr: 1.0000e-05
# Epoch 80/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8199 - accuracy: 0.6929
# Epoch 80: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 492s 1s/step - loss: 0.8199 - accuracy: 0.6929 - val_loss: 0.8893 - val_accuracy: 0.6708 - lr: 1.0000e-05
# Epoch 81/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8214 - accuracy: 0.6922
# Epoch 81: val_accuracy did not improve from 0.67694
# 358/358 [==============================] - 491s 1s/step - loss: 0.8214 - accuracy: 0.6922 - val_loss: 0.8895 - val_accuracy: 0.6745 - lr: 1.0000e-05
# Epoch 82/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8232 - accuracy: 0.6927
# Epoch 82: val_accuracy improved from 0.67694 to 0.67938, saving model to best_model.h5
# 358/358 [==============================] - 493s 1s/step - loss: 0.8232 - accuracy: 0.6927 - val_loss: 0.8840 - val_accuracy: 0.6794 - lr: 1.0000e-05
# Epoch 83/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8196 - accuracy: 0.6953
# Epoch 83: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 490s 1s/step - loss: 0.8196 - accuracy: 0.6953 - val_loss: 0.8889 - val_accuracy: 0.6750 - lr: 1.0000e-05
# Epoch 84/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8202 - accuracy: 0.6953
# Epoch 84: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 491s 1s/step - loss: 0.8202 - accuracy: 0.6953 - val_loss: 0.8862 - val_accuracy: 0.6768 - lr: 1.0000e-05
# Epoch 85/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8220 - accuracy: 0.6949
# Epoch 85: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 491s 1s/step - loss: 0.8220 - accuracy: 0.6949 - val_loss: 0.8924 - val_accuracy: 0.6769 - lr: 1.0000e-05
# Epoch 86/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8215 - accuracy: 0.6929
# Epoch 86: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 492s 1s/step - loss: 0.8215 - accuracy: 0.6929 - val_loss: 0.8889 - val_accuracy: 0.6759 - lr: 1.0000e-05
# Epoch 87/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8194 - accuracy: 0.6917
# Epoch 87: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 491s 1s/step - loss: 0.8194 - accuracy: 0.6917 - val_loss: 0.8863 - val_accuracy: 0.6771 - lr: 1.0000e-05
# Epoch 88/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8108 - accuracy: 0.6945
# Epoch 88: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 492s 1s/step - loss: 0.8108 - accuracy: 0.6945 - val_loss: 0.8955 - val_accuracy: 0.6715 - lr: 1.0000e-05
# Epoch 89/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8125 - accuracy: 0.6952
# Epoch 89: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 492s 1s/step - loss: 0.8125 - accuracy: 0.6952 - val_loss: 0.8944 - val_accuracy: 0.6749 - lr: 1.0000e-05
# Epoch 90/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8218 - accuracy: 0.6954
# Epoch 90: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 491s 1s/step - loss: 0.8218 - accuracy: 0.6954 - val_loss: 0.8944 - val_accuracy: 0.6764 - lr: 1.0000e-05
# Epoch 91/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8153 - accuracy: 0.6931
# Epoch 91: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 492s 1s/step - loss: 0.8153 - accuracy: 0.6931 - val_loss: 0.8885 - val_accuracy: 0.6762 - lr: 1.0000e-05
# Epoch 92/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8137 - accuracy: 0.6939
# Epoch 92: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 491s 1s/step - loss: 0.8137 - accuracy: 0.6939 - val_loss: 0.8887 - val_accuracy: 0.6754 - lr: 1.0000e-05
# Epoch 93/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8070 - accuracy: 0.7010
# Epoch 93: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 492s 1s/step - loss: 0.8070 - accuracy: 0.7010 - val_loss: 0.8904 - val_accuracy: 0.6780 - lr: 1.0000e-05
# Epoch 94/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8095 - accuracy: 0.6973
# Epoch 94: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 490s 1s/step - loss: 0.8095 - accuracy: 0.6973 - val_loss: 0.8939 - val_accuracy: 0.6743 - lr: 1.0000e-05
# Epoch 95/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8032 - accuracy: 0.6989
# Epoch 95: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 490s 1s/step - loss: 0.8032 - accuracy: 0.6989 - val_loss: 0.8916 - val_accuracy: 0.6761 - lr: 1.0000e-05
# Epoch 96/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8114 - accuracy: 0.6986
# Epoch 96: val_accuracy did not improve from 0.67938
# 358/358 [==============================] - 491s 1s/step - loss: 0.8114 - accuracy: 0.6986 - val_loss: 0.8898 - val_accuracy: 0.6769 - lr: 1.0000e-05
# Epoch 97/100
# 358/358 [==============================] - ETA: 0s - loss: 0.8085 - accuracy: 0.6991
# Epoch 97: val_accuracy did not improve from 0.67938
# Restoring model weights from the end of the best epoch: 82.
# 358/358 [==============================] - 491s 1s/step - loss: 0.8085 - accuracy: 0.6991 - val_loss: 0.8957 - val_accuracy: 0.6750 - lr: 1.0000e-05
# Epoch 97: early stopping

# %%
# Load the best saved model
model.load_weights('best_model.h5')

# Evaluate on test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy: {test_acc*100:.2f}%')

# Generate predictions
y_pred = model.predict(test_images)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_labels, axis=1)

# Classification report
print(classification_report(y_true, y_pred_classes, target_names=['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']))

# Confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix(y_true, y_pred_classes), 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral'],
            yticklabels=['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral'])
plt.title('Confusion Matrix')
plt.show()
# Out:
# 225/225 [==============================] - 31s 139ms/step - loss: 0.9367 - accuracy: 0.6658
# Test Accuracy: 66.58%
# 225/225 [==============================] - 31s 135ms/step
#               precision    recall  f1-score   support
#
#        Angry       0.58      0.64      0.61       958
#      Disgust       0.69      0.50      0.58       111
#         Fear       0.58      0.38      0.46      1024
#        Happy       0.85      0.87      0.86      1774
#          Sad       0.57      0.52      0.54      1247
#     Surprise       0.76      0.77      0.77       831
#      Neutral       0.56      0.71      0.63      1233
#
#     accuracy                           0.67      7178
#    macro avg       0.66      0.63      0.64      7178
# weighted avg       0.67      0.67      0.66      7178

# %%
# Save the final model
model.save('emotion_detection_model.h5')

# Convert to TensorFlow Lite for mobile deployment (optional)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('emotion_detection.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Bhushan\AppData\Local\Temp\tmph22lv9kp\assets
# INFO:tensorflow:Assets written to: C:\Users\Bhushan\AppData\Local\Temp\tmph22lv9kp\assets

# %%
import os
import matplotlib.pyplot as plt
from sklearn.metrics import (roc_curve, auc, precision_recall_curve, 
                            confusion_matrix, classification_report)
from sklearn.preprocessing import label_binarize  # Added this import
import seaborn as sns
import numpy as np
import json
from math import pi  # For radar chart


# Create Evaluation_Metrics directory if it doesn't exist
os.makedirs('Evaluation_Metrics', exist_ok=True)

# Set professional style for all plots
plt.style.use('seaborn')
sns.set_palette("husl")
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3

# 1. Enhanced ROC Curve (Multi-class)
def save_roc_curve(y_true, y_pred):
    y_true_bin = label_binarize(y_true, classes=range(7))
    fpr, tpr, roc_auc = {}, {}, {}
    
    plt.figure(figsize=(12, 8))
    for i in range(7):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], lw=2.5, 
                label=f'{emotion_labels[i]} (AUC = {roc_auc[i]:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--', lw=2, alpha=0.5)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title('Multiclass ROC Curves', fontsize=14, pad=20)
    plt.legend(loc="lower right", frameon=True, bbox_to_anchor=(1.4, 0))
    plt.tight_layout()
    plt.savefig('Evaluation_Metrics/ROC_Curve.png', dpi=300, bbox_inches='tight')
    plt.close()
    
    # Save ROC AUC values
    with open('Evaluation_Metrics/roc_auc_values.json', 'w') as f:
        json.dump({emotion_labels[i]: float(roc_auc[i]) for i in range(7)}, f)

# 2. Precision-Recall Curve with F1 contours
def save_pr_curve(y_true, y_pred):
    y_true_bin = label_binarize(y_true, classes=range(7))
    precision, recall, pr_auc = {}, {}, {}
    
    plt.figure(figsize=(12, 8))
    for i in range(7):
        precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_pred[:, i])
        pr_auc[i] = auc(recall[i], precision[i])
        plt.plot(recall[i], precision[i], lw=2.5, 
                label=f'{emotion_labels[i]} (AUC = {pr_auc[i]:.2f})')
    
    # Add F1-score contours
    f_scores = np.linspace(0.2, 0.8, num=4)
    for f_score in f_scores:
        x = np.linspace(0.01, 1)
        y = f_score * x / (2 * x - f_score)
        plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2, linestyle='--')
        plt.annotate(f'F1={f_score:.1f}', xy=(0.9, y[-1] + 0.02), alpha=0.5)
    
    plt.xlabel('Recall', fontsize=12)
    plt.ylabel('Precision', fontsize=12)
    plt.title('Precision-Recall Curves with F1 Contours', fontsize=14, pad=20)
    plt.legend(loc="upper right", frameon=True, bbox_to_anchor=(1.4, 1))
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.tight_layout()
    plt.savefig('Evaluation_Metrics/PR_Curve.png', dpi=300, bbox_inches='tight')
    plt.close()

# 3. Enhanced Confusion Matrix
def save_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    plt.figure(figsize=(14, 12))
    sns.heatmap(cm_norm, 
               annot=True, 
               fmt='.2f', 
               cmap='Blues',
               annot_kws={'size': 10},
               xticklabels=emotion_labels.values(),
               yticklabels=emotion_labels.values(),
               linewidths=0.5,
               cbar_kws={'shrink': 0.75})
    
    plt.title('Normalized Confusion Matrix', fontsize=16, pad=20)
    plt.xlabel('Predicted Label', fontsize=14)
    plt.ylabel('True Label', fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.savefig('Evaluation_Metrics/Confusion_Matrix.png', dpi=300, bbox_inches='tight')
    plt.close()
    
    # Save raw confusion matrix
    np.save('Evaluation_Metrics/confusion_matrix_raw.npy', cm)

# 4. Class Distribution Radar Chart
def save_radar_chart(y_true, y_pred):
    from math import pi
    
    true_counts = np.bincount(y_true, minlength=7)
    pred_counts = np.bincount(y_pred, minlength=7)
    
    categories = list(emotion_labels.values())
    N = len(categories)
    
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    
    plt.figure(figsize=(10, 10))
    ax = plt.subplot(111, polar=True)
    
    # True distribution
    true_values = true_counts / true_counts.sum()
    true_values = np.append(true_values, true_values[0])
    ax.plot(angles, true_values, linewidth=2, linestyle='solid', 
           label='True Distribution', color='#3498db')
    ax.fill(angles, true_values, '#3498db', alpha=0.1)
    
    # Predicted distribution
    pred_values = pred_counts / pred_counts.sum()
    pred_values = np.append(pred_values, pred_values[0])
    ax.plot(angles, pred_values, linewidth=2, linestyle='solid', 
           label='Predicted Distribution', color='#e74c3c')
    ax.fill(angles, pred_values, '#e74c3c', alpha=0.1)
    
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    plt.xticks(angles[:-1], categories, color='grey', size=12)
    ax.set_rlabel_position(0)
    plt.yticks([0.1, 0.2, 0.3, 0.4], ["10%", "20%", "30%", "40%"], color="grey", size=10)
    plt.ylim(0, 0.5)
    plt.title('Class Distribution Radar Chart', size=16, y=1.1)
    plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
    plt.savefig('Evaluation_Metrics/Radar_Chart.png', dpi=300, bbox_inches='tight')
    plt.close()

# 5. Enhanced F1-Score by Class with Error Bars
def save_f1_scores(y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)
    metrics = {
        'precision': [report[str(i)]['precision'] for i in range(7)],
        'recall': [report[str(i)]['recall'] for i in range(7)],
        'f1-score': [report[str(i)]['f1-score'] for i in range(7)],
        'support': [report[str(i)]['support'] for i in range(7)]
    }
    
    x = np.arange(7)
    width = 0.25
    
    plt.figure(figsize=(14, 8))
    rects1 = plt.bar(x - width, metrics['precision'], width, label='Precision', color='#2ecc71')
    rects2 = plt.bar(x, metrics['recall'], width, label='Recall', color='#e67e22')
    rects3 = plt.bar(x + width, metrics['f1-score'], width, label='F1-Score', color='#9b59b6')
    
    # Add value labels
    for rects, offset in zip([rects1, rects2, rects3], [-width, 0, width]):
        for rect in rects:
            height = rect.get_height()
            plt.text(rect.get_x() + rect.get_width()/2. + offset, height + 0.01,
                    f'{height:.2f}', ha='center', va='bottom', fontsize=9)
    
    plt.xlabel('Emotion Class', fontsize=12)
    plt.ylabel('Score', fontsize=12)
    plt.title('Precision, Recall and F1-Score by Class', fontsize=14, pad=20)
    plt.xticks(x, emotion_labels.values())
    plt.legend(loc='upper right', frameon=True)
    plt.ylim(0, 1.1)
    plt.grid(axis='y', linestyle='--', alpha=0.3)
    plt.tight_layout()
    plt.savefig('Evaluation_Metrics/F1_Scores.png', dpi=300, bbox_inches='tight')
    plt.close()
    
    # Save full classification report
    with open('Evaluation_Metrics/classification_report.json', 'w') as f:
        json.dump(report, f, indent=4)

# 6. Prediction Confidence Distribution
def save_confidence_distribution(y_true, y_pred):
    plt.figure(figsize=(14, 8))
    for i in range(7):
        class_mask = y_true == i
        if np.any(class_mask):
            confidences = y_pred[class_mask, i]
            sns.kdeplot(confidences, label=emotion_labels[i], lw=2.5)
    
    plt.title('Prediction Confidence Distribution by Class', fontsize=14, pad=20)
    plt.xlabel('Model Confidence', fontsize=12)
    plt.ylabel('Density', fontsize=12)
    plt.legend(title='Emotion Class')
    plt.grid(axis='y', linestyle='--', alpha=0.3)
    plt.xlim(0, 1)
    plt.tight_layout()
    plt.savefig('Evaluation_Metrics/Confidence_Distribution.png', dpi=300, bbox_inches='tight')
    plt.close()

# Generate and save all plots
print("\n\033[1mGenerating Comprehensive Evaluation Metrics...\033[0m")
save_roc_curve(y_true, y_pred)
save_pr_curve(y_true, y_pred)
save_confusion_matrix(y_true, y_pred_classes)
save_radar_chart(y_true, y_pred_classes)
save_f1_scores(y_true, y_pred_classes)
save_confidence_distribution(y_true, y_pred)

print("\n\033[1mAll evaluation metrics saved to Evaluation_Metrics folder:\033[0m")
print(os.listdir('Evaluation_Metrics'))
# Out:
# C:\Users\Bhushan\AppData\Local\Temp\ipykernel_12332\3242762299.py:16: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# Generating Comprehensive Evaluation Metrics...
#
# All evaluation metrics saved to Evaluation_Metrics folder:
# ['classification_report.json', 'Confidence_Distribution.png', 'Confusion_Matrix.png', 'confusion_matrix_raw.npy', 'F1_Scores.png', 'PR_Curve.png', 'Radar_Chart.png', 'roc_auc_values.json', 'ROC_Curve.png']
